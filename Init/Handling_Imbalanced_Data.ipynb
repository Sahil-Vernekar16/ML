# %%
import pandas as pd

# %%
dataset_df = pd.read_csv('credit_data.csv')
# Out:
# <ipython-input-2-1ab5e2f6f050>:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset_df = pd.read_csv('credit_data.csv')

# %%
dataset_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ...   -0.1083  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
dataset_df.shape
# Out:
# (286784, 31)

# %%
dataset_df.value_counts('Class')
# Out:
# Class
# 0.0    286288
# 1.0       495
# Name: count, dtype: int64

# %% [markdown]
# # Handling Imbalanced Data

# %%
real = dataset_df[dataset_df.Class==0]
fraud = dataset_df[dataset_df.Class==1]

# %%
real.shape
# Out:
# (286288, 31)

# %%
fraud.shape
# Out:
# (495, 31)

# %%
real_samples=real.sample(495)

# %%
new = pd.concat([real_samples,fraud],axis=0)

# %%
new.shape
# Out:
# (990, 31)

# %%
new.head()
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# 106108  69828.0 -0.998448  0.403444  0.094996 -1.759402 -0.792856 -1.077985
# 45044   42182.0  1.217079  0.113060  0.464474  1.214080 -0.332896 -0.290960
# 24317   33173.0  0.937670 -0.365582  0.226184  0.878529 -0.427080 -0.415165
# 86047   61061.0  1.358215 -0.968311 -0.735208 -1.786550  1.097660  3.457507
# 112709  72771.0  1.048632  0.488954  0.298408  2.293790  0.458198  0.549308
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 106108  1.129708  0.305832  0.511890  ...  0.281059  0.637814  0.267733
# 45044  -0.067534 -0.026634  0.595642  ...  -0.29005 -0.691914 -0.033775
# 24317   0.278320 -0.229029  0.274442  ... -0.140352 -0.533992 -0.192927
# 86047  -1.394836  0.889233 -0.660668  ...  0.095118 -0.047099 -0.028901
# 112709  0.161992  0.202147 -1.191316  ...  0.070414  0.173041 -0.019629
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 281840  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 282120  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 282126  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 283121  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 283651  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 281840 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 282120 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 282126 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 283121 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 283651  0.223050 -0.068384  0.577829  ...  -0.16435 -0.295135 -0.072173
#
# ...

# %%
new.value_counts('Class')
# Out:
# Class
# 0.0    495
# 1.0    495
# Name: count, dtype: int64
