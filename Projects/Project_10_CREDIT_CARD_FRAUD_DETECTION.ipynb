# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data Collection and Preprocessing

# %%
dataset_df = pd.read_csv('creditcard.csv')

# %%
dataset_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
dataset_df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
dataset_df.shape
# Out:
# (284807, 31)

# %%
dataset_df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
legit = dataset_df[dataset_df.Class == 0]
fraud = dataset_df[dataset_df.Class == 1]

# %%
legit = legit.sample(n=492)

# %%
new_dataset_df = pd.concat([legit, fraud], axis=0)

# %%
new_dataset_df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 145938   87296.0 -2.583019  3.662807 -1.057357  4.062628 -0.515769  0.658052
# 19486    30320.0 -0.974029  0.800200  2.804832 -0.048769  0.197837 -0.224326
# 113251   72995.0  1.428176 -0.974952 -0.600164 -1.676789  1.019882  3.681140
# 215        142.0  1.211406  0.007850  0.950798  1.137646 -0.495189  0.301371
# 260121  159412.0 -0.960542  2.025785 -1.197011 -0.515547  0.394494 -0.146850
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 145938 -0.784870  1.857897 -2.004535  ... -0.121115 -0.359108  0.387247
# 19486   0.867125 -0.340689  0.098624  ... -0.049465  0.117695 -0.165779
# 113251 -1.616129  0.960934 -0.319232  ...  0.285195  0.763860 -0.181624
# 215    -0.518350  0.095426  0.817592  ... -0.107248 -0.057153 -0.118933
# 260121 -0.680728 -3.127116 -0.579908  ... -0.782820 -0.613423  0.471899
#
# ...

# %%
new_dataset_df.shape
# Out:
# (984, 31)

# %%
new_dataset_df['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
X = new_dataset_df.drop(columns='Class', axis=1)
Y = new_dataset_df['Class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# # Model Building and Testing

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
training_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(training_prediction, Y_train)
print(training_data_accuracy)

# %%
testing_prediction = model.predict(X_test)
testing_data_r2_score = r2_score( Y_test, testing_prediction)
print(testing_data_r2_score)
# Out:
# 0.7360338074623789

# %% [markdown]
# # Custom Input

# %%
input = (93853,-6.18585747765758,7.10298492227346,-13.0304552638937,8.01082339822486,-7.88523736131971,-3.97454999359808,-12.2296077786617,4.9712317023058,-4.24830701294998,-12.9654812039222,8.68830799242781,-17.1829184301947,0.0695769150313325,-14.1161560074304,0.959031717400206,-12.3753337375636,-18.716764511809,-6.52201457322122,3.51795494036344,0.483930108481186,2.50277241039945,0.481691289576756,0.480957977547458,0.360318638811951,-0.293354295977635,-0.199193157971208,-0.203917328209747,0.398927185850218,44.9)
input = np.asarray(input)
input = input.reshape(1,-1)
prediction = model.predict(input)
print(prediction)
# Out:
# [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
