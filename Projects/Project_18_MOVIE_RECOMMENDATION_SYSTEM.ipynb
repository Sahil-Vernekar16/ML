# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import difflib

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
features = ['genres', 'keywords' , 'title', 'cast' , 'director']

# %%
for feature in features:
    movies[feature] = movies[feature].fillna('')

# %%
combined_features = movies['genres'] + ' ' + movies['keywords'] + ' ' + movies['title'] + ' ' + movies['cast'] + ' ' + movies['director']

# %%
vectorizer = TfidfVectorizer()

# %%
combined_features = vectorizer.fit_transform(combined_features)

# %%
similarity = cosine_similarity(combined_features)

# %%
print(similarity.shape)
# Out:
# (4803, 4803)

# %%
user_input = input('Enter a movie:')
# Out:
# Enter a movie:Iron Man

# %%
all_movies = movies['title'].tolist()

# %%
find_similar_movies = difflib.get_close_matches(user_input, all_movies)

# %%
find_similar_movies
# Out:
# ['Iron Man', 'Iron Man 3', 'Iron Man 2']

# %%
index_of_movie = movies[movies.title == find_similar_movies[0]]['index'].values[0]

# %%
index_of_movie
# Out:
# 68

# %%
similar_movies = list(enumerate(similarity[index_of_movie]))
# Out:
# [(0, 0.03820479283185877),
#  (1, 0.05206063928974137),
#  (2, 0.01578327638656363),
#  (3, 0.006752521295049248),
#  (4, 0.03936482471189696),
#  (5, 0.038671400266703904),
#  (6, 0.03265838979316074),
#  (7, 0.24939575139642803),
#  (8, 0.00834515317288504),
#  (9, 0.08035131102426192),
#  (10, 0.07665126999514103),
#  (11, 0.014302564154722329),
#  (12, 0.03467496555713231),
#  (13, 0.013134719815127295),
#  (14, 0.13525097038518138),
#  (15, 0.007518755599815317),
#  (16, 0.26149150161226525),
#  (17, 0.01399673912649712),
#  (18, 0.027700163149060177),
#  (19, 0.05530613438750896),
#  (20, 0.10880345831692026),
#  (21, 0.013831767036962792),
#  (22, 0.007940601772538221),
#  (23, 0.008171746572668089),
#  (24, 0.014399320373674114),
#  (25, 0.0),
#  (26, 0.21798583097089483),
#  (27, 0.03503914744316817),
#  (28, 0.06791392418779262),
#  (29, 0.01589715671181649),
#  (30, 0.11395831617694531),
#  (31, 0.4501478856626725),
#  (32, 0.0075287782970280236),
# ...

# %%
similar_movies = sorted(similar_movies, key= lambda x:x[1], reverse=True)

# %%
similar_movies
# Out:
# [(68, 1.0),
#  (79, 0.5823703122299547),
#  (31, 0.4501478856626725),
#  (16, 0.26149150161226525),
#  (7, 0.24939575139642803),
#  (26, 0.21798583097089483),
#  (182, 0.2036041634265524),
#  (511, 0.18851754191714495),
#  (3623, 0.18414407506271144),
#  (203, 0.1834644281230056),
#  (85, 0.17238159996014207),
#  (64, 0.17181263079161158),
#  (101, 0.16922816884013825),
#  (174, 0.1659589180055054),
#  (2487, 0.15866906790142526),
#  (788, 0.15464366634921217),
#  (126, 0.14854108276469463),
#  (1740, 0.14744941894714572),
#  (46, 0.14347556039943615),
#  (38, 0.14243016492938249),
#  (1553, 0.1403614002573652),
#  (33, 0.1401183422787205),
#  (783, 0.136703524896348),
#  (2651, 0.13643359996002014),
#  (14, 0.13525097038518138),
#  (138, 0.13160603852319847),
#  (2411, 0.13070227544828467),
#  (2442, 0.12874760883754943),
#  (3166, 0.12510007003682852),
#  (661, 0.12083088932802495),
#  (307, 0.11917071805249413),
#  (607, 0.11804888356905906),
#  (2221, 0.11669984335069673),
# ...

# %%
for i in range(30):
  index = similar_movies[i][0]
  title = movies[movies.index == index]['title'].values[0]
  print(i+1 , title)
# Out:
# 1 Iron Man
# 2 Iron Man 2
# 3 Iron Man 3
# 4 The Avengers
# 5 Avengers: Age of Ultron
# 6 Captain America: Civil War
# 7 Ant-Man
# 8 X-Men
# 9 Made
# 10 X2
# 11 Captain America: The Winter Soldier
# 12 X-Men: Apocalypse
# 13 X-Men: First Class
# 14 The Incredible Hulk
# 15 Duets
# 16 Deadpool
# 17 Thor: The Dark World
# 18 Kick-Ass 2
# 19 X-Men: Days of Future Past
# 20 The Amazing Spider-Man 2
# 21 Se7en
# 22 X-Men: The Last Stand
# 23 Mortdecai
# 24 The Good Night
# 25 Man of Steel
# 26 The Last Airbender
# 27 The Best Man Holiday
# 28 Southland Tales
# 29 The Best Man
# 30 Zathura: A Space Adventure

# %% [markdown]
# # Movie Recommendation System

# %%
user_input = input('Enter a movie:')
find_similar_movies = difflib.get_close_matches(user_input, all_movies)
index_of_movie = movies[movies.title == find_similar_movies[0]]['index'].values[0]
similar_movies = list(enumerate(similarity[index_of_movie]))
similar_movies = sorted(similar_movies, key= lambda x:x[1], reverse=True)
for i in range(30):
  index = similar_movies[i][0]
  title = movies[movies.index == index]['title'].values[0]
  print(i+1 , title)
# Out:
# Enter a movie:Avatar
# 1 Avatar
# 2 Guardians of the Galaxy
# 3 Aliens
# 4 Alien
# 5 Galaxy Quest
# 6 Star Trek Into Darkness
# 7 Star Trek Beyond
# 8 Space Dogs
# 9 Jason X
# 10 Alien³
# 11 Gravity
# 12 Lost in Space
# 13 Zathura: A Space Adventure
# 14 Cargo
# 15 Trekkies
# 16 Space Chimps
# 17 Pocahontas
# 18 Lockout
# 19 Space Cowboys
# 20 Machete Kills
# 21 Planet of the Apes
# 22 Clash of the Titans
# 23 Silent Running
# 24 Gettysburg
# 25 Moonraker
# 26 The Astronaut's Wife
# 27 Wing Commander
# 28 Imaginary Heroes
# 29 Sunshine
# 30 Star Wars: Clone Wars: Volume 1
